# %%
import os
from safetensors import safe_open

# %%
model_dir = '/mnt/llm/Mistral-Nemo-Instruct-2407'

# %%
hf_model_state_dict = {}

# %%
for i in range(1, 6):
    ckpt_path = os.path.join(model_dir, f'model-{i:05d}-of-00005.safetensors')
    print(ckpt_path)
    weights = safe_open(ckpt_path, 'pt', 'cpu')
    weights = {k: weights.get_tensor(k) for k in weights.keys()}
    hf_model_state_dict.update(weights)
# Out:
# /mnt/llm/Mistral-Nemo-Instruct-2407/model-00001-of-00005.safetensors
# /mnt/llm/workspace/zhaozhiyu/install/miniconda3/envs/pmx/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:258: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# /mnt/llm/Mistral-Nemo-Instruct-2407/model-00002-of-00005.safetensors
# /mnt/llm/Mistral-Nemo-Instruct-2407/model-00003-of-00005.safetensors
# /mnt/llm/Mistral-Nemo-Instruct-2407/model-00004-of-00005.safetensors
# /mnt/llm/Mistral-Nemo-Instruct-2407/model-00005-of-00005.safetensors

# %%
for k in hf_model_state_dict.keys():
    print(k)
# Out:
# model.embed_tokens.weight
# model.layers.0.input_layernorm.weight
# model.layers.0.mlp.down_proj.weight
# model.layers.0.mlp.gate_proj.weight
# model.layers.0.mlp.up_proj.weight
# model.layers.0.post_attention_layernorm.weight
# model.layers.0.self_attn.k_proj.weight
# model.layers.0.self_attn.o_proj.weight
# model.layers.0.self_attn.q_proj.weight
# model.layers.0.self_attn.v_proj.weight
# model.layers.1.input_layernorm.weight
# model.layers.1.mlp.down_proj.weight
# model.layers.1.mlp.gate_proj.weight
# model.layers.1.mlp.up_proj.weight
# model.layers.1.post_attention_layernorm.weight
# model.layers.1.self_attn.k_proj.weight
# model.layers.1.self_attn.o_proj.weight
# model.layers.1.self_attn.q_proj.weight
# model.layers.1.self_attn.v_proj.weight
# model.layers.2.input_layernorm.weight
# model.layers.2.mlp.down_proj.weight
# model.layers.2.mlp.gate_proj.weight
# model.layers.2.mlp.up_proj.weight
# model.layers.2.post_attention_layernorm.weight
# model.layers.2.self_attn.k_proj.weight
# ...

# %%
hf_model_state_dict['model.layers.0.self_attn.q_proj.weight'].shape
# Out:
# torch.Size([4096, 5120])

# %%
hf_model_state_dict['model.layers.0.self_attn.o_proj.weight'].shape
# Out:
# torch.Size([5120, 4096])

# %%
None is not None
# Out:
# False

# %%
None is None
# Out:
# True
